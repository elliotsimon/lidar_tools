# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

# %% [markdown]
# # Pt.1 Risoe

# %%
df = pd.read_csv('small_area_risoe', sep='\t', header=None)

# %%
df.head(2)
# Out:
#            0           1     2  3  4
# 0  694600.06  6176497.44  1.02  2  1
# 1  694600.13  6176497.78  1.90  4  2

# %%
df_small = df.iloc[::10,:]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df_small[0], df_small[1], df_small[2], marker='.', c=df_small[2])
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Pt.2 - met-mast

# %%
df_tower = pd.read_csv('risoe_tower', sep='\t', header=None)

# %%
df_tower.head(2)
# Out:
#            0           1     2  3  4
# 0  694000.01  6176308.17  5.45  2  1
# 1  694000.01  6176399.69  5.24  2  1

# %%
df_tower[2].describe()
# Out:
# count    177012.000000
# mean          6.720248
# std           7.646362
# min          -1.110000
# 25%           2.920000
# 50%           3.780000
# 75%           6.050000
# max         128.090000
# Name: 2, dtype: float64

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df_tower[0], df_tower[1], df_tower[2], marker='.')
# Out:
# <img src="data:image/png;base64,...">
